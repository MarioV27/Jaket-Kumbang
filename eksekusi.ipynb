# %%
# %pip install -r requirements.txt
# %pip install torch torchvision torchaudio
# %pip install -U ultralytics
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.4 MB 653.6 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/14.4 MB 656.4 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/14.4 MB 731.4 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/14.4 MB 731.4 kB/s eta 0:00:20
#    ---------------------------------------- 0.2/14.4 MB 700.2 kB/s eta 0:00:21
#     --------------------------------------- 0.2/14.4 MB 620.6 kB/s eta 0:00:23
#     --------------------------------------- 0.2/14.4 MB 655.6 kB/s eta 0:00:22
#     --------------------------------------- 0.3/14.4 MB 655.4 kB/s eta 0:00:22
# ...

# %% [markdown]
# 0: 'aqila', 1: 'brant', 2: 'devina', 3: 'encie', 4: 'jaket kumbang', 5: 'jaket lain', 6: 'jane', 7: 'manusia', 8: 'seragam', 9: 'syifa'

# %%
# !python detect.py --weights best.onnx --img 640 --conf 0.5 --source data.mp4 --device cpu
# Out:
# requirements: C:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\requirements.txt not found, check failed.
# detect: weights=['best.onnx'], source=data.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  4a67d6a Python-3.11.0 torch-2.1.0+cu118 CPU
#
# Loading best.onnx for ONNX Runtime inference...
# video 1/1 (1/131) C:\Jaket-Kumbang\yolov5\data.mp4: 640x640 1 devina, 1 jaket kumbang, 2 jaket lains, 3 manusias, 119.7ms
# video 1/1 (2/131) C:\Jaket-Kumbang\yolov5\data.mp4: 640x640 1 devina, 1 jaket kumbang, 2 jaket lains, 3 manusias, 123.8ms
# ...
